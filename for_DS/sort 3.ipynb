# %%
def partition(xs, start, end):
    follower = leader = start
    while leader < end:
        if xs[leader] <= xs[end]:
            xs[follower], xs[leader] = xs[leader], xs[follower]
            follower += 1
        leader += 1
    xs[follower], xs[end] = xs[end], xs[follower]
    return follower

def _quicksort(xs, start, end):
    if start >= end:
        return
    p = partition(xs, start, end)
    _quicksort(xs, start, p-1)
    _quicksort(xs, p+1, end)
    
def quicksort(xs):
    _quicksort(xs, 0, len(xs)-1)

# %%
import time

# %%
import numpy as np
def IA1(k):
    return np.random.randint(1,1001,size=2**k)
def IA2(k):
    l = list(range(1,2**k+1,1))  #加上list參考https://blog.csdn.net/wanglin_lin/article/details/50819657
    loc = np.random.choice(2**k,100,replace=False) #選取位置
    r_numbers = np.random.randint(1,1001,100) #生成隨機數
    for i in range(100):
        l[loc[i]]=r_numbers[i]
    return l

# %%
t_list =[]
for k in range(10,31):
    k_t_list =[]
    for times in range(10):
        input_array = IA1(k)
        t = time.perf_counter()
        quicksort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list, k_t_list,end='')
    t_list.append(np.mean(k_t_list))
# Out:
# Input Array Size:2^ 21  times: 0   time: 2020-05-02 20:50:31 [0.007466873099110672, 0.01631139479977719, 0.03518595850000565, 0.09282785120049084, 0.22195898729987676, 0.6174581988008867, 1.937048025000331, 6.795572709100088, 26.012295454199194, 102.9477410962998, 403.16526652579995] [1597.0702004589984] 404.6844268800014, 402.88630060599826, 406.73233795000124, 404.2319822310019, 402.37383075400066, 396.7204165209987, 400.9020912679989, 404.74712824699964]299182, 0.08466105700063054, 0.106195126001694, 0.09072917500088806, 0.09616814400214935, 0.10440566599936574]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a01e5b6207bb> in <module>
#       5         input_array = IA1(k)
#       6         t = time.perf_counter()
# ----> 7         quicksort(input_array)
#       8         t = time.perf_counter() - t
#       9         k_t_list.append(t)
#
# <ipython-input-1-bbd4d7d5808f> in quicksort(xs)
#      17
#      18 def quicksort(xs):
# ---> 19     _quicksort(xs, 0, len(xs)-1)
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
# ---> 16     _quicksort(xs, p+1, end)
#      17
#      18 def quicksort(xs):
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      13         return
#      14     p = partition(xs, start, end)
# ---> 15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#      17
#
# <ipython-input-1-bbd4d7d5808f> in _quicksort(xs, start, end)
#      12     if start >= end:
#      13         return
# ---> 14     p = partition(xs, start, end)
#      15     _quicksort(xs, start, p-1)
#      16     _quicksort(xs, p+1, end)
#
# <ipython-input-1-bbd4d7d5808f> in partition(xs, start, end)
#       2     follower = leader = start
#       3     while leader < end:
# ----> 4         if xs[leader] <= xs[end]:
#       5             xs[follower], xs[leader] = xs[leader], xs[follower]
#       6             follower += 1
#
# KeyboardInterrupt:

# %%
print(t_list)
# Out:
# [0.009217152999999811, 0.015907415300000238, 0.03961968159999998, 0.09077790220000015, 0.22798511989999995, 0.641183891500001, 2.1102529995999992, 6.826125175100003, 25.2229301996, 96.91113049500004, 370.95127869349994, 1493.26335268]

# %%
import sys
sys.setrecursionlimit(1000000)

# %%
t_list =[]
for k in range(10,31):
    k_t_list =[]
    for times in range(10):
        input_array = IA2(k)
        t = time.perf_counter()
        quicksort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
    t_list.append(np.mean(k_t_list))
# Out:
# Input Array Size:2^ 19  times: 0   time: 2020-05-01 17:59:16 [0.008711552800059507, 0.024860434799938956, 0.07312618949990793, 0.2005704572999548, 0.939666980300035, 3.3200218112999664, 16.254383205699924, 76.53295124040001, 220.9134366721999] [290.8255714950001] 94.60467343499977, 185.59503938299986, 124.53413043199998, 192.6478917889999, 77.87213524399976, 201.68919569299942, 112.43246184300006, 227.55636074300037]

# %%
print(t_list)
# Out:
# [0.00902878819997568, 0.032443283899988275, 0.10312474499996824, 0.30657585019998806, 0.8005451615999846, 3.1609155277000127, 8.59411398049997]
