# %%
import time

# %%
def heapify(arr, n, i):
      # Find largest among root and children
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2
  
    if l < n and arr[i] < arr[l]:
        largest = l
  
    if r < n and arr[largest] < arr[r]:
        largest = r
  
      # If root is not largest, swap with largest and continue heapifying
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)
  
  
def heapSort(arr):
    n = len(arr)
  
      # Build max heap
    for i in range(n, -1, -1):
        heapify(arr, n, i)
  
    for i in range(n-1, 0, -1):
          # Swap
        arr[i], arr[0] = arr[0], arr[i]

# %%
import numpy as np
def IA1(k):
    return np.random.randint(1,1001,size=2**k)
def IA2(k):
    l = list(range(1,2**k+1,1))  #加上list參考https://blog.csdn.net/wanglin_lin/article/details/50819657
    loc = np.random.choice(2**k,100,replace=False) #選取位置
    r_numbers = np.random.randint(1,1001,100) #生成隨機數
    for i in range(100):
        l[loc[i]]=r_numbers[i]
    return l

# %%
t_list =[]
for k in range(10,31):
    k_t_list =[]
    for times in range(10):
        input_array = IA1(k)
        t = time.perf_counter()
        heapSort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
    t_list.append(np.mean(k_t_list))
# Out:
# Input Array Size:2^ 29  times: 0   time: 2020-05-01 22:38:19 [0.0018512337999979423, 0.004900777199998885, 0.008002158299998997, 0.016858857900000145, 0.03072926879999969, 0.06344248450000052, 0.12509867019999987, 0.2639236454999995, 0.47547874410000046, 0.9543037771000001, 1.8930732759000022, 3.700271837299998, 8.3235329414, 16.5633070623, 32.473208187799976, 66.46183938019996, 130.43147843100002, 227.5264324279, 457.1115706385999] [961.2732569649997]3, 454.3274712900002, 450.3758264899998, 468.99883954600045, 458.21608634099994, 455.75699685699965, 462.7527665479993, 450.48636362899924, 453.52062801300053]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e47a5a6508cb> in <module>
#       5         input_array = IA1(k)
#       6         t = time.perf_counter()
# ----> 7         heapSort(input_array)
#       8         t = time.perf_counter() - t
# ...

# %%
t_list =[0.0018512337999979423, 0.004900777199998885, 0.008002158299998997, 0.016858857900000145, 0.03072926879999969, 0.06344248450000052, 0.12509867019999987, 0.2639236454999995, 0.47547874410000046, 0.9543037771000001, 1.8930732759000022, 3.700271837299998, 8.3235329414, 16.5633070623, 32.473208187799976, 66.46183938019996, 130.43147843100002, 227.5264324279, 457.1115706385999]

# %%
print(t_list)
# Out:
# None

# %%
for k in range(30,31):
    k_t_list =[]
    for times in range(2):
        input_array = IA1(k)
        t = time.perf_counter()
        heapSort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
    t_list.append(np.mean(k_t_list))
# Out:
# Input Array Size:2^ 30  times: 1   time: 2020-05-01 23:52:51 None [2099.5265956900002, 2155.172472923001]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-3e6890732f9f> in <module>
#       8         k_t_list.append(t)
#       9         print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
# ---> 10     t_list.append(np.mean(k_t_list))
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
np.mean([2099.5265956900002, 2155.172472923001])
# Out:
# 2127.3495343065006

# %%
t_list =[]
for k in range(10,31):
    k_t_list =[]
    for times in range(10):
        input_array = IA2(k)
        t = time.perf_counter()
        heapSort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
    t_list.append(np.mean(k_t_list))
# Out:
# Input Array Size:2^ 13  times: 8   time: 2020-05-02 00:06:15 [0.008506654800112302, 0.002067025000178546, 0.00413054770015151] [0.00841243800095981, 0.007388464999166899, 0.008297942000353942, 0.008302403000925551, 0.008068328999797814, 0.009298799001044245, 0.007883397998739383, 0.008156104000590858, 0.008168592001311481]
# Input Array Size:2^ 27  times: 9   time: 2020-05-02 01:02:38 [0.008506654800112302, 0.002067025000178546, 0.00413054770015151, 0.00821582450025744, 0.016514085399830947, 0.03413094150000688, 0.07082082980050472, 0.13619635649993142, 0.2543175205000807, 0.4963451625999369, 0.9892298198999925, 2.111108250699908, 4.29422633109989, 8.700336049999896, 17.094593835700106, 34.963781478500096, 69.1076045717] [151.45424580200051, 157.66769665699758, 148.32414530099777, 154.37139660400135, 153.4648315910017, 160.74536168199847, 173.49917375800214, 156.86623111100198, 152.1073819589983, 151.08355564200247]

# %%
[0.008506654800112302, 0.002067025000178546, 0.00413054770015151, 0.00821582450025744, 0.016514085399830947, 0.03413094150000688, 0.07082082980050472, 0.13619635649993142, 0.2543175205000807, 0.4963451625999369, 0.9892298198999925, 2.111108250699908, 4.29422633109989, 8.700336049999896, 17.094593835700106, 34.963781478500096, 69.1076045717]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ecb04dc3e97b> in <module>
# ----> 1 t_list
#
# NameError: name 't_list' is not defined

# %%
np.mean([151.45424580200051, 157.66769665699758, 148.32414530099777, 154.37139660400135, 153.4648315910017, 160.74536168199847, 173.49917375800214, 156.86623111100198, 152.1073819589983, 151.08355564200247])
# Out:
# 155.95840201070024

# %%
t_list =[]
for k in range(30,31):
    k_t_list =[]
    for times in range(10):
        input_array = IA2(k)
        t = time.perf_counter()
        heapSort(input_array)
        t = time.perf_counter() - t
        k_t_list.append(t)
        print('\rInput Array Size:2^', k,' times:',times,'  time:',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),t_list,k_t_list,end='')
    t_list.append(np.mean(k_t_list))

# %%
np.mean([572.8875381780003, 561.6286973810002, 579.83872475, 530.3369997050004, 556.0826771259999, 543.2107905410003, 570.538388555, 572.5327773680001, 543.2892041669993])
# Out:
# 558.9273108634445
