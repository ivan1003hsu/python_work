# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote
from urllib.request import urlopen

year="2019"
month = "10"
date="1"


keyword = quote("柯文哲".encode("utf8"))

www = "https://www.google.com/search?q="+keyword+"&biw=1375&bih=632&source=lnt&tbs=cdr%3A1%2Ccd_min%3A"+month+"%2F"+date+"%2F"+year+"%2Ccd_max%3A"+month+"%2F"+date+"%2F"+year+"&tbm=nws"

r= requests.get(www)

if r.status_code == requests.codes.ok:
    soup = BeautifulSoup(r, features='lxml')
    print("ok")
    
items = soup.find_all("div",{'class':"gG0TJc"})

sel = items.find_all("a",{'class':"lLrAf"})
for s in sel:
    print(s.text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-cf630e9b9af3> in <module>
#      13 www = "https://www.google.com/search?q="+keyword+"&biw=1375&bih=632&source=lnt&tbs=cdr%3A1%2Ccd_min%3A"+month+"%2F"+date+"%2F"+year+"%2Ccd_max%3A"+month+"%2F"+date+"%2F"+year+"&tbm=nws"
#      14
# ---> 15 r= urlopen(www).read()
#      16
#      17 if r.status_code == requests.codes.ok:
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# ...

# %%
r.status_code
# Out:
# 200

# %%
www
# Out:
# 'https://www.google.com/search?q=%E6%9F%AF%E6%96%87%E5%93%B2&biw=1375&bih=632&source=lnt&tbs=cdr%3A1%2Ccd_min%3A10%2F1%2F2019%2Ccd_max%3A10%2F1%2F2019&tbm=nws'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>柯文哲 - Google 搜尋</title><script nonce="bc9nm/n+tfZmXe8CNx94IA==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...
